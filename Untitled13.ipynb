# %% [markdown]
# <a href="https://colab.research.google.com/github/yeeun0813/baewha/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
import cv2
from google.colab.patches import cv2_imshow
img_path = 'ss.jpg'
img = cv2.imread(img_path)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
import torch
print(torch.__version__)
# Out:
# 2.5.1+cu124

# %%
if torch.cuda.is_available():
    device = torch.device('cuda:0')
else:
    device = torch.device('cpu')
print(device)
# Out:
# cpu
